# %% [markdown]
# # N-gramas
# ## Mitsiu Alejandro Carreño Sarabia

# %%
# Importamos las librerías necesarias
import requests
import nltk
nltk.download('stopwords')
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer


url_libro = "https://www.gutenberg.org/files/1938/1938-0.txt"

res = requests.get(url_libro)
res.encoding = res.apparent_encoding
documento = res.text

stop_words = nltk.corpus.stopwords.words('english')

# También se puede usar ngrams de nltk 
#tokens = nltk.ngrams(documento.split(), 2)

# Agregamos el parametro ngram_range=(2,2) para generar 2-gramas
vectorizador = CountVectorizer(ngram_range = (2, 2), input="content", analyzer="word", stop_words=stop_words)
matriz_frecuencias = vectorizador.fit_transform([documento])

tabla_frecuencias = pd.DataFrame(
    np.transpose(matriz_frecuencias.toarray()),
    index=vectorizador.get_feature_names_out(),
    columns = ["conteo"]
)

tabla_frecuencias.sort_values("conteo", ascending=False).head(50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                      conteo
# said nekhludoff         128
# old man                  94
# project gutenberg        87
# mary pavlovna            64
# gutenberg tm             57
# old woman                54
# nekhludoff asked         52
# nekhludoff said          48
# public prosecutor        47
# every one                46
# young man                41
# nekhludoff went          37
# nekhludoff thought       33
# political prisoners      31
# vera doukhova            30
# agraphena petrovna       29
# little girl              29
# nekhludoff felt          28
# said old                 26
# thought nekhludoff       25
# long time                24
# one another              24
# could see                23
# asked nekhludoff         23
# said inspector           22
# nekhludoff could         22
# hard labour              22
# katerina ivanovna        21
# ...

# %% [markdown]
# Un caso de uso para los n-gramas en especifico con los 2-gramas puede ser un modelo de texto predictivo como el que tienen los celulares de autocompletado, que toman la útima palabra escrita para intentar predecir la siguiente.
#
# Al seguir siendo un texto natural, es necesario seguir empleando stopwords. Respecto al stemming, tengo mis dudas, ya que al ser 2-gramas, por ejemplo existen elementos "said nekhludoff" y "nekhludoff said" en donde el said toma dos significados "dicho" y "dijo" y no sé como el stemming pueda valorar que aunque es la misma palabra, se esta usando de maneras distintas.
