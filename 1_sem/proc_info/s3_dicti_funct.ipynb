# %% [markdown]
# ##Diccionarios
# Estructura de datos que puede guardar multiples valores y cada uno tiene una clave para identificarlo
#
# {"clave":"valor"}
#
# ![texto alternativo](https://ep01.epimg.net/cultura/imagenes/2014/10/17/babelia/1413557916_366993_1413560515_noticia_normal.jpg)

# %%
# json dictionario o dict
persona = {
    "nombre":"Poncho",
    "apellido" : "Hernández",
    "anio_nacimiento": 1992,
    "mes_nacimiento": 10,
    "es_casado": False,
}

# %% [markdown]
# ## Ejercicio B
#
# Dado un diccionario con la información de una persona calcula la edad y escribe un texto similar al siguiente
#
# "La persona llamada PEDRO tiene 25 años"

# %% [markdown]
# # Funciones
#
# instrucciones de código reutilizables,
# debe cumplir con un objetivo, es decir, agregar una funcionalidad
#
# sintaxis
#
#
#
# ```
# def nombre_funcion():
#   print("código a ejecutar")
# ```
#
#
#
# ## Parámetros de funciones
# los valores con las que trabaja una función
#
# ## Bibliotecas
# Conjunto de funcionalidades que alguién más implementó y que puedes utilizar.

# %%
def saludar():
  print("Hola te saludo")

# %%
saludar()
saludar()
saludar()
# Out:
# Hola te saludo
# Hola te saludo
# Hola te saludo

# %%
def saludar_a(nombre):
  print("Hola " + nombre + ", te saludo")

# %%
saludar_a("Juan")
saludar_a("Pedro")
saludar_a("Arnulfo")
# Out:
# Hola Juan, te saludo
# Hola Pedro, te saludo
# Hola Arnulfo, te saludo

# %%
import random

def tira_el_dado():
  numero = random.randint(1,6)
  print("el numero es",numero)
  return numero

# %%
a = tira_el_dado()
print(a)
# Out:
# el numero es 2
# 2

# %% [markdown]
# Ejercicio C
#
# 1) Crea una función que recibe como parámetro, anio y mes de nacimineto, luego calcula y regresa la edad
#
# 2) Crea otra función que dada una edad te diga si es mayor de edad
#
# TIP: Utiliza las 2 funciones, primero calcula la edad luego con el resultado pasálo como parámetro y decide si es mayor de edad.
