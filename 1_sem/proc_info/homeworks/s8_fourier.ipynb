# %% [markdown]
# # Mitsiu Alejandro Carreño Sarabia - E23S-18014
# ## Tarea semana 8 - Transformada de Fourier

# %% [markdown]
# 1- A task assigned to you to measure the temperature of the room.Thus everyday at noon, you measure the temperature and record the value. You measured for 30 days. What's the frequency of the temperature signal you get?
# R- La frecuencia de las mediciones es 1 por día

# %% [markdown]
# 2- What's the relationship of the frequency and period of a wave?
# R- Ambos se refieren a una contabilización respecto al tiempo, el periodo mide la cantidad de tiempo en que se completa un ciclo, la frecuencia contabiliza cuanto del ciclo a avanzado en un tiempo especifico
# Matematicamente periodo = 1/frecuencia

# %% [markdown]
# 3- What's the difference of period and wavelength? What are the similarities between them?
# R- Ambos periodo y wavelength miden la distancia entre dos crestas de una onda, pero lo hacen en unidades distintas, el periodo mide el tiempo entre crestas y el wavelength la distancia entre crestas

# %% [markdown]
# 4- What are the time domain and frequency domain representation of a signal?
# R- Los dominios se refieren a la unidad en el eje x, cuando observamos una señal, la graficamos sobre el tiempo, cuando realizamos la transformación de Fourier, descomponemos esa señal y la graficamos sobre el dominio de las frecuencias, en la que el tiempo realmente no es relevante porque descomponemos en señales sinoidales que son ciclicas, pero nos es relevantes otras caracterisitcas del seno como la amplitud, y frecuencia.

# %% [markdown]
# 5- Generate two sinals signal 1 is a sine wave with 5 Hz, amplitude 3 and phase shift 3; signal 2 is a sine wave with 2 Hz, amplitude 2 and phase shift -2 Plot the signal for 2 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-poster')
# %matplotlib inline

# sampling rate
sr = 100.0
# sampling interval
ts = 1.0/sr
t = np.arange(0,2, ts)

plt.figure(figsize=(6,10))
plt.subplot(311)
plt.ylabel("Amplitude")

##### Signal 1
freq = 5
ampl = 3
phase = 3
y1 = ampl* np.sin(2*np.pi * freq * t + phase)
plt.plot(t, y1, 'b')

##### Signal 2
freq = 2
ampl = 2
phase = -2
y2 = ampl * np.sin(2*np.pi * freq * t + phase)
plt.subplot(312)
plt.plot(t, y2, 'b')
plt.ylabel("Amplitude")


##### Signals combined
y1 +=  y2
plt.subplot(313)
plt.plot(t, y1, 'b')
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")
plt.show()
# Out:
# /tmp/ipykernel_3295/1787525083.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# 6- Sample the signal you generated in problem 5 using sampling rate 5, 10, 20, 50 and 100 Hz and see the difference between differetent sampling rates.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-poster')
# %matplotlib inline

def GetTimeSampleRate(sr):
    '''
    Descrip
        Generate the sample rate array 
    Input:
        sample rate 
    '''
    #sampling interval
    ts = 1.0/sr
    return np.arange(0,2,ts)

plt.figure(figsize=(8,20))

# Sample rate 5
y = 3* np.sin(2*np.pi * 5 * GetTimeSampleRate(5) + 3) \
    + 2 * np.sin(2*np.pi * 2 * GetTimeSampleRate(5) + -2)
plt.subplot(511)
plt.plot(GetTimeSampleRate(5), y, 'b')
plt.ylabel("Amp")

# Sample rate 10
y = 3* np.sin(2*np.pi * 5 * GetTimeSampleRate(10) + 3) \
    + 2 * np.sin(2*np.pi * 2 * GetTimeSampleRate(10) + -2)
plt.subplot(512)
plt.plot(GetTimeSampleRate(10), y, 'b')
plt.ylabel("Amp")

# Sample rate 20
y = 3* np.sin(2*np.pi * 5 * GetTimeSampleRate(20) + 3) \
    + 2 * np.sin(2*np.pi * 2 * GetTimeSampleRate(20) + -2)
plt.subplot(513)
plt.plot(GetTimeSampleRate(20), y, 'b')
plt.ylabel("Amp")

# Sample rate 50
y = 3* np.sin(2*np.pi * 5 * GetTimeSampleRate(50) + 3) \
    + 2 * np.sin(2*np.pi * 2 * GetTimeSampleRate(50) + -2)
plt.subplot(514)
plt.plot(GetTimeSampleRate(50), y, 'b')
plt.ylabel("Amp")

# Sample rate 100
y = 3* np.sin(2*np.pi * 5 * GetTimeSampleRate(100) + 3) \
    + 2 * np.sin(2*np.pi * 2 * GetTimeSampleRate(100) + -2)
plt.subplot(515)
plt.plot(GetTimeSampleRate(100), y, 'b')
plt.ylabel("Amp")
plt.xlabel("Time (s)")
# Out:
# /tmp/ipykernel_3295/1113111081.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# 7- Given a signal t = [0,1,2,3] and y = [0,3,2,0] find the real DFT of X. Write the expression for the inverse DFT. Note that, don't use Python to find the results, instead write out the equations and calculate the values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8- What are the amplitude and phase of the DFT values for a signal?
# R- Ambas la amplitud y la fase estan codificadas en un número complejo que cuenta con una parte real y una imaginaria

# %% [markdown]
# 9- We implement DFT previously, can you implement the inverse Discrete Fourier Transform in Python similarly?

# %%
def IDFT(x):
    """
    Function to calculate the 
    inverse discrete Fourier transform
    of a 1-D real-valued signal x
    """
    N = len(x)
    n = np.arange(N)
    k = n.reshape((N,1))
    e = np.exp((2j*np.pi * k * n)/N)
    X = np.dot(e, x)
    return 1/N * X

# %% [markdown]
# 10- Use the DFT function and inverse DFT we implemented and generate the amplitude spectrum for the signal you generated in problem 5. Normalize the DFT amplitude to get the correct corresponding time domain and amplitude

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-poster')
# %matplotlib inline

def DFT(x):
    """
    Function to calculate the 
    discrete Fourier Transform
    of a 1D real-valued signal x
    """
    
    N = len(x)
    n = np.arange(N)
    k = n.reshape((N,1))
    #e = np.exp(-2j * np.pi * k * n / N)
    e = np.exp((-2j * np.pi * k * n) / N)
    
    X = np.dot(e, x) # Dot product of two arrays
    
    return X

# sampling rate
sr = 100.0
# sampling interval
ts = 1.0/sr
t = np.arange(0,2, ts)

##### Signal 1
freq = 5
ampl = 3
phase = 3
y = ampl* np.sin(2*np.pi * freq * t + phase)

##### Signal 2
freq = 2
ampl = 2
phase = -2
y += ampl * np.sin(2*np.pi * freq * t + phase)

##### Graph signal
plt.figure(figsize=(6,6))
plt.subplot(211)
plt.plot(t, y, 'b')
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")

## Discrete Fourier Transform
X = DFT(y)

# Calculate the frequency
N = len(y)
n = np.arange(N)
T = N/sr
freq = n/T
plt.subplot(212)
plt.stem(freq, abs(X), 'b', \
        markerfmt=" ", basefmt="-b")
plt.xlabel("Freq (Hz)")
plt.ylabel("DFT Amplitude |X(freq)|")
plt.show()
# Out:
# /tmp/ipykernel_3295/689501159.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# 11- Can you describe the tricks used in FFT to make the computation faster?
# R- Como se puede apreciar en la grafica de frequencias del ejercicio anterior, la transformación de Fourier genera senos simetricos, en realidad con DFT estamos realizando más computaciones de las que realmente son absolutamente necesarias, FFT toma una aproximación de Dividir y conquistar en la que el problema se divide en problemas similares pero más pequeños, con ello se termina con un muchos problemas sencillos en lugar de un problema complejo, ello para la computadora es más sencillo de procesar. Para generar los problemas más sencillos, se emplea una técnica llamada "Recursividad" en la cuál el mismo algoritmo se invoca n veces pero cada vez con inputs más pequeños.

# %% [markdown]
# 12- Use the fft and ifft function from scipy to repeat problem 10

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.fftpack

plt.style.use('seaborn-poster')
# %matplotlib inline

# sampling rate
sr = 100.0
# sampling interval
ts = 1.0/sr
t = np.arange(0,2, ts)

##### Signal 1
freq = 5
ampl = 3
phase = 3
y = ampl* np.sin(2*np.pi * freq * t + phase)

##### Signal 2
freq = 2
ampl = 2
phase = -2
y += ampl * np.sin(2*np.pi * freq * t + phase)

##### Graph signal
plt.figure(figsize=(6,6))
plt.subplot(211)
plt.plot(t, y, 'b')
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")

temp_fft = sp.fftpack.fft(y)
plt.subplot(212)
plt.plot(t, abs(temp_fft), 'b')
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")
# Out:
# /tmp/ipykernel_3295/1086409542.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# 13- Adding a random normal distributon noise into the signal in problem 5 using numpy and plot the FFT amplitude spectrum, what do you see?

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-poster')
# %matplotlib inline

def DFT(x):
    """
    Function to calculate the 
    discrete Fourier Transform
    of a 1D real-valued signal x
    """
    
    N = len(x)
    n = np.arange(N)
    k = n.reshape((N,1))
    #e = np.exp(-2j * np.pi * k * n / N)
    e = np.exp((-2j * np.pi * k * n) / N)
    
    X = np.dot(e, x) # Dot product of two arrays
    
    return X

# sampling rate
sr = 100.0
# sampling interval
ts = 1.0/sr
t = np.arange(0,2, ts)

##### Signal 1
freq = 5
ampl = 3
phase = 3
y = ampl* np.sin(2*np.pi * freq * t + phase)

##### Signal 2
freq = 2
ampl = 2
phase = -2
y += ampl * np.sin(2*np.pi * freq * t + phase)

##### Noise
np.random.seed(10)
y_noise = y + np.random.normal(0,2,size= len(y))

##### Graph signal
plt.figure(figsize=(6,6))
plt.subplot(211)
plt.plot(t, y_noise, 'b')
plt.ylabel("Amplitude")
plt.xlabel("Time (s)")

## Discrete Fourier Transform
X = DFT(y)

# Calculate the frequency
N = len(y)
n = np.arange(N)
T = N/sr
freq = n/T
plt.subplot(212)
plt.stem(freq, abs(X), 'b', \
        markerfmt=" ", basefmt="-b")
plt.xlabel("Freq (Hz)")
plt.ylabel("DFT Amplitude |X(freq)|")
plt.show()
# Out:
# /tmp/ipykernel_3295/1331706601.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# R- The result of the Fourier transform seems unaffected by the noise
